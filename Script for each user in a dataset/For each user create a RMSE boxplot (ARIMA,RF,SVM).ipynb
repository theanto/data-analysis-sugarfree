# %% [markdown]
# ### Import dataset

# %% [markdown]
# ### Script that for each user in dataset (dataset.cvs) compute a RMSE with Arima, Random Forest and SVM with PSW from 3-36h and Ph from 15-60min.

# %% [markdown]
# ### For each user will be create a folder (Uid) with image of 3 methods.
#
# #### In this example i have 3users:
#
# ##### -User 1 XGHcBspXfRQj3jD91ty8u2UuT483
# ##### -User 2 Z8RsBpxhnkebK5fvahVCmfV7icO2
# ##### -User 3 fLqw0dU8z4brI2Jg74ps3pHqLak1

# %%
# %run -i "script.py"
# Out:
# User 0 9OesCogfhLUKXkUQRhkLq8scAw02
# User 1 XGHcBspXfRQj3jD91ty8u2UuT483
# User 2 Z8RsBpxhnkebK5fvahVCmfV7icO2
# User 3 fLqw0dU8z4brI2Jg74ps3pHqLak1
# Arima 1:
# --- 1829.5251474380493 Seconds for computation ---
# RF 1:
# --- 1631.9277317523956 Seconds for computation ---
# SVM 1:
# --- 77.55628991127014 Seconds for computation ---
# Arima 2:
# --- 3118.1226222515106 Seconds for computation ---
# RF 2:
# --- 2951.5514209270477 Seconds for computation ---
# SVM 2:
# --- 147.2733290195465 Seconds for computation ---
# Arima 3:
# --- 61.63145875930786 Seconds for computation ---
# RF 3:
# --- 126.01952409744263 Seconds for computation ---
# SVM 3:
# --- 5.1292924880981445 Seconds for computation ---
