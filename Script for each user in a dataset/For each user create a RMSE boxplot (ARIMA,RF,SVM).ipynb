# %% [markdown]
# ### Import dataset

# %% [markdown]
# ### Script that for each user in dataset (dataset.cvs) compute a RMSE with Arima, Random Forest and SVM with PSW from 3-36h and Ph from 15-60min.

# %% [markdown]
# ### For each user will be create a folder (Uid) with image of 3 methods.
#
# #### In this example i have 3users:
#
# ##### -User 1 XGHcBspXfRQj3jD91ty8u2UuT483
# ##### -User 2 Z8RsBpxhnkebK5fvahVCmfV7icO2
# ##### -User 3 fLqw0dU8z4brI2Jg74ps3pHqLak1

# %%
# %run -i "script.py"
# Out:
# User 0 9OesCogfhLUKXkUQRhkLq8scAw02
# User 1 XGHcBspXfRQj3jD91ty8u2UuT483
# User 2 Z8RsBpxhnkebK5fvahVCmfV7icO2
# User 3 fLqw0dU8z4brI2Jg74ps3pHqLak1
# Arima 1:
# --- 15069.475577354431 Seconds for computation ---
# RF 1:
# --- 3745.3212563991547 Seconds for computation ---
# SVM 1:
# --- 169.7211627960205 Seconds for computation ---
# Arima 2:
# --- 20224.63184118271 Seconds for computation ---
# RF 2:
# --- 2764.468136548996 Seconds for computation ---
# SVM 2:
# --- 179.28102779388428 Seconds for computation ---
# Arima 3:
# --- 60.6064715385437 Seconds for computation ---
# RF 3:
# --- 121.58620047569275 Seconds for computation ---
# SVM 3:
# --- 5.418507814407349 Seconds for computation ---
