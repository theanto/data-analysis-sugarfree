# %%
import pandas as pd 

data = pd.read_csv("sleep.json", parse_dates=['time'] )

# %%
data
# Out:
#                               uid                time     level   sec
# 0    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-16 22:21:30      wake  1770
# 1    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-16 22:51:00     light   150
# 2    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-16 22:53:30      wake   870
# 3    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-16 23:08:00     light   180
# 4    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-16 23:11:00      deep  2850
# 5    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-16 23:58:30       rem   840
# 6    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 00:12:30     light  1320
# 7    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 00:34:30      wake   210
# 8    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 00:38:00     light   480
# 9    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 00:46:00      deep   420
# 10   fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 00:53:00     light   120
# 11   fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 00:55:00      wake   270
# ...

# %%
dataM =data.reset_index().set_index('time')

# %%
pd.set_option('display.max_rows', 4000)


print(dataM)
# Out:
#                      index                           uid     level   sec
# time
# 2019-12-16 22:21:30      0  fLqw0dU8z4brI2Jg74ps3pHqLak1      wake  1770
# 2019-12-16 22:51:00      1  fLqw0dU8z4brI2Jg74ps3pHqLak1     light   150
# 2019-12-16 22:53:30      2  fLqw0dU8z4brI2Jg74ps3pHqLak1      wake   870
# 2019-12-16 23:08:00      3  fLqw0dU8z4brI2Jg74ps3pHqLak1     light   180
# 2019-12-16 23:11:00      4  fLqw0dU8z4brI2Jg74ps3pHqLak1      deep  2850
# 2019-12-16 23:58:30      5  fLqw0dU8z4brI2Jg74ps3pHqLak1       rem   840
# 2019-12-17 00:12:30      6  fLqw0dU8z4brI2Jg74ps3pHqLak1     light  1320
# 2019-12-17 00:34:30      7  fLqw0dU8z4brI2Jg74ps3pHqLak1      wake   210
# 2019-12-17 00:38:00      8  fLqw0dU8z4brI2Jg74ps3pHqLak1     light   480
# 2019-12-17 00:46:00      9  fLqw0dU8z4brI2Jg74ps3pHqLak1      deep   420
# 2019-12-17 00:53:00     10  fLqw0dU8z4brI2Jg74ps3pHqLak1     light   120
# 2019-12-17 00:55:00     11  fLqw0dU8z4brI2Jg74ps3pHqLak1      wake   270
# ...

# %%
#data =dataM.reset_index().set_index('time').resample('15min').mean()
data = data[data.level != "wake"]
data = data[data.level != "awake"]

# %%
data
# Out:
#                               uid                time     level   sec
# 1    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-16 22:51:00     light   150
# 3    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-16 23:08:00     light   180
# 4    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-16 23:11:00      deep  2850
# 5    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-16 23:58:30       rem   840
# 6    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 00:12:30     light  1320
# 8    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 00:38:00     light   480
# 9    fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 00:46:00      deep   420
# 10   fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 00:53:00     light   120
# 12   fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 00:59:30     light   270
# 14   fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 01:08:30     light  2160
# 16   fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 01:49:30     light  2850
# 17   fLqw0dU8z4brI2Jg74ps3pHqLak1 2019-12-17 02:37:00      deep   300
# ...

# %%
data =dataM.groupby('uid').resample('15min').mean().dropna()

# %%
pd.set_option('display.max_rows', 8000)


print(data)
# Out:
#                                                   index     sec
# uid                          time
# XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 10:15:00  184.0  3040.0
#                              2020-01-21 12:45:00  186.5   210.0
#                              2020-01-21 22:00:00  188.5   570.0
#                              2020-01-21 22:15:00  190.0   480.0
#                              2020-01-21 22:30:00  191.0   690.0
#                              2020-01-21 22:45:00  192.5   585.0
#                              2020-01-21 23:00:00  195.0   280.0
#                              2020-01-21 23:15:00  197.0  1080.0
#                              2020-01-21 23:30:00  198.0  1680.0
#                              2020-01-22 00:00:00  199.0   600.0
#                              2020-01-22 00:15:00  200.5  1275.0
#                              2020-01-22 00:45:00  202.0   360.0
#                              2020-01-22 01:00:00  203.0  1740.0
# ...

# %%
data =data.reset_index()

# %%
data
# Out:
#                               uid                time  index     sec
# 0    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 10:15:00  184.0  3040.0
# 1    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 12:45:00  186.5   210.0
# 2    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 22:00:00  188.5   570.0
# 3    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 22:15:00  190.0   480.0
# 4    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 22:30:00  191.0   690.0
# 5    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 22:45:00  192.5   585.0
# 6    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 23:00:00  195.0   280.0
# 7    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 23:15:00  197.0  1080.0
# 8    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 23:30:00  198.0  1680.0
# 9    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-22 00:00:00  199.0   600.0
# 10   XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-22 00:15:00  200.5  1275.0
# 11   XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-22 00:45:00  202.0   360.0
# 12   XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-22 01:00:00  203.0  1740.0
# ...

# %%
del data['index']

# %%
data
# Out:
#                               uid                time     sec
# 0    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 10:15:00  3040.0
# 1    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 12:45:00   210.0
# 2    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 22:00:00   570.0
# 3    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 22:15:00   480.0
# 4    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 22:30:00   690.0
# 5    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 22:45:00   585.0
# 6    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 23:00:00   280.0
# 7    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 23:15:00  1080.0
# 8    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-21 23:30:00  1680.0
# 9    XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-22 00:00:00   600.0
# 10   XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-22 00:15:00  1275.0
# 11   XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-22 00:45:00   360.0
# 12   XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-22 01:00:00  1740.0
# 13   XGHcBspXfRQj3jD91ty8u2UuT483 2020-01-22 01:30:00   480.0
# ...

# %%
export_csv = data.to_csv (r'sleep.csv', index = None, header=True)
